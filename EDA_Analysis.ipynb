# %% [markdown]
# <a href="https://colab.research.google.com/github/Padmakanth2004/United-Nation-Global-Terrorism-Analysis-Using-ML-unsupervised-Learning/blob/main/EDA_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Global Terrorism Analysis using Exploratory Data Analysis

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Individual/Team
# ##### **Team Member 1 -** Kolanu Padmakanth Reddy
# ##### **Team Member 2 -**
# ##### **Team Member 3 -**
# ##### **Team Member 4 -**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project performs an in-depth Exploratory Data Analysis (EDA) on the Global
# Terrorism Dataset with the objective of identifying patterns, trends, and key
# insights related to terrorist incidents worldwide. The dataset contains detailed
# information such as the year of the incident, location (country and region),
# type of attack, target category, and the number of casualties involved.
#
# The initial phase of the analysis involved data cleaning and preparation.
# Missing values were handled using statistical techniques like median for
# numerical variables and mode for categorical variables to preserve the natural
# distribution of the data. Important features were selected to simplify the dataset,
# and a new metric called 'impact_score' was introduced by combining fatalities
# and injuries to measure the severity of each incident. Duplicate entries were
# also removed to ensure data quality and reliability.
#
# Various visualizations were developed to better understand the dataset.
# The time-series analysis indicated a steady rise in terrorist activities over
# the years, particularly after the early 2000s, reflecting an increase in global
# security challenges. This trend highlights the need for continuous monitoring
# and stronger preventive strategies.
#
# Further analysis at the country level showed that terrorist incidents are not
# uniformly distributed but are concentrated in specific nations. This suggests
# the existence of high-risk areas that require focused attention. Similarly,
# regional analysis revealed that areas such as the Middle East & North Africa
# and South Asia experience a significantly higher number of incidents compared
# to other parts of the world.
#
# When analyzing attack methods, it was observed that a limited number of attack
# types, especially bombings and explosions, account for a large proportion of
# incidents. This indicates a pattern in the choice of attack strategies, which
# can be useful for designing targeted countermeasures.
#
# The distribution of casualties demonstrated that while most incidents result
# in relatively low impact, a small number of events lead to extremely high
# casualties. This uneven distribution emphasizes the importance of being prepared
# for rare but severe incidents that can have major consequences.
#
# From a business and strategic perspective, these findings are highly useful.
# Organizations can leverage these insights to identify safer regions for operations,
# enhance security protocols, and develop effective risk mitigation strategies.
# At the same time, the increasing frequency of attacks and concentration in certain
# regions may negatively affect economic growth by discouraging investments,
# reducing tourism, and creating uncertainty in the business environment.
#
# Overall, this analysis provides a clear understanding of global terrorism trends.
# It demonstrates how data-driven insights can support better decision-making,
# improve safety measures, and help organizations operate more effectively in
# high-risk and uncertain conditions.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Analyze the Global Terrorism Dataset to identify patterns in terrorist activities,
# including trends over years, regions affected, attack types, and casualties.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# This dataset helps understand global terrorism trends.
# Insights can help governments and organizations improve security planning,
# risk assessment, and counter-terrorism strategies.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
df = pd.read_csv("Global Terrorism Data.csv", encoding='latin1', on_bad_lines='skip', engine='python')
print("Dataset Loaded Successfully")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
print(df.duplicated().sum())

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(df.isnull().sum())

# %%
# Visualizing the missing values
df2=df.isnull().sum()
df2.plot(kind='bar',figsize=(30,5))

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset used in this project is the Global Terrorism Dataset, which contains
# detailed information about terrorist incidents that occurred worldwide over several decades.
#
# It includes various features such as the year of the attack, country, region,
# type of attack, target category, and the number of casualties (killed and wounded).
# The dataset provides both categorical and numerical data, allowing comprehensive analysis
# of patterns and trends in terrorist activities.
#
# It is a large and real-world dataset, which requires proper data cleaning and preprocessing
# before analysis due to the presence of missing values and inconsistencies.
# Overall, the dataset is suitable for understanding global terrorism trends and deriving
# meaningful insights through exploratory data analysis.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns

# %%
# Dataset Describe
df.describe()

# %% [markdown]
# ### Variables Description

# %% [markdown]
# The dataset contains multiple variables that describe different aspects of terrorist incidents:
#
# 1. iyear:
#    Represents the year in which the terrorist attack occurred.
#
# 2. country_txt:
#    Name of the country where the incident took place.
#
# 3. region_txt:
#    Indicates the geographical region of the attack (e.g., South Asia, Middle East).
#
# 4. attacktype1_txt:
#    Describes the type of attack carried out, such as bombing, armed assault, or hijacking.
#
# 5. targtype1_txt:
#    Specifies the type of target involved, such as civilians, military, government, etc.
#
# 6. nkill:
#    Number of people killed in the attack.
#
# 7. nwound:
#    Number of people wounded in the attack.
#
# 8. total_casualties / impact_score:
#    A derived variable calculated as the sum of killed and wounded, representing
#    the overall impact of the incident.
#
# These variables provide both categorical and numerical information, enabling
# detailed analysis of patterns, trends, and severity of terrorist activities.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df.nunique()

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready
df['country_txt'].fillna("Unknown", inplace=True)
df['region_txt'].fillna("Unknown", inplace=True)
df['attacktype1_txt'].fillna("Unknown", inplace=True)
df['targtype1_txt'].fillna("Unknown", inplace=True)

df['nkill'].fillna(0, inplace=True)
df['nwound'].fillna(0, inplace=True)

df['total_casualties'] = df['nkill'] + df['nwound']

df = df[['iyear', 'country_txt', 'region_txt',
         'attacktype1_txt', 'targtype1_txt',
         'nkill', 'nwound', 'total_casualties']]

df.drop_duplicates(inplace=True)

df['iyear'] = df['iyear'].astype(int)

df.head()

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Data preprocessing steps performed:
#
# 1. Handled missing values by replacing categorical nulls with 'Unknown'
#    and numerical nulls with 0.
# 2. Created a new feature 'total_casualties' for better analysis.
# 3. Selected only relevant columns to simplify the dataset.
# 4. Removed duplicate records to maintain data integrity.
# 5. Ensured correct data types for analysis.
#
# The dataset is now clean and ready for exploratory data analysis.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
yearly_data = df.groupby('iyear').size()

plt.figure(figsize=(10,6))
plt.plot(yearly_data.index, yearly_data.values, marker='o')

plt.title("Trend of Terrorist Attacks Over Years")
plt.xlabel("Year")
plt.ylabel("Number of Attacks")

plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A line chart was chosen because the data represents a time-based trend (year-wise attacks).
# Line charts are best suited for showing how values change over a continuous period.
#
# It helps in clearly visualizing the increase or decrease in terrorist activities over the years,
# making it easier to identify patterns, peaks, and trends in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that terrorist attacks have generally increased over the years,
# with a noticeable rise after the year 2000.
#
# There are certain peak periods where the number of attacks is significantly high,
# indicating times of increased global conflict and instability.
#
# Overall, the trend highlights that terrorism has become more frequent over time,
# especially in recent decades.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights gained can help create a positive business impact.
#
# By identifying trends in terrorist activities, organizations and governments
# can improve risk management, enhance security planning, and make better decisions
# regarding resource allocation. Businesses can avoid high-risk regions, plan safer
# operations, and protect assets and employees.
#
# However, the insights also indicate negative growth in terms of increasing terrorist
# activities over time. This rise can lead to economic instability, reduced investments,
# disruptions in business operations, and decreased tourism in affected regions.
#
# Thus, while the insights are valuable for strategic planning, they also highlight
# serious challenges that can negatively impact global business environments.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
country_data = (df.groupby('country_txt').size().sort_values(ascending=False).head(10))

plt.figure(figsize=(10,6))
plt.barh(country_data.index, country_data.values)

plt.title("Top 10 Countries by Number of Attacks")
plt.xlabel("Number of Attacks")
plt.ylabel("Country")

plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A horizontal bar chart was chosen because the data involves comparing
# multiple categories (countries) based on the number of attacks.
#
# This type of chart makes it easy to compare values across categories and
# is especially useful when category names are long, ensuring better readability.
#
# It clearly highlights the countries with the highest number of attacks,
# making the differences more understandable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that terrorist attacks are highly concentrated in a few countries,
# while many other countries experience relatively fewer incidents.
#
# A small number of countries account for the majority of attacks, indicating
# regional hotspots of terrorism. This uneven distribution highlights that certain
# areas are significantly more affected and require focused attention and security measures.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights can create a positive business impact.
#
# By identifying countries with higher terrorist activity, businesses and organizations
# can make informed decisions about where to expand, invest, or operate. It helps in
# risk assessment, better security planning, and protecting employees and assets.
#
# However, the insights also indicate negative growth in high-risk countries.
# Frequent terrorist attacks can reduce foreign investments, affect tourism,
# disrupt supply chains, and slow down economic development.
#
# This creates an unfavorable business environment in those regions, leading
# to long-term economic challenges.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
attack_data = (df.groupby('attacktype1_txt').size().sort_values(ascending=False).head(8))

# Plot as pie chart (different from usual bar charts)
plt.figure(figsize=(8,8))
plt.pie(attack_data.values, labels=attack_data.index, autopct='%1.1f%%', startangle=140)

plt.title("Distribution of Major Attack Types")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart is used to represent the proportion of different attack types
# in the dataset. It helps in understanding which attack types contribute
# the most to total incidents in a simple and visual way.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that a few attack types account for a large proportion of total incidents,
# with bombing/explosion being the most dominant.
#
# This indicates that terrorist groups tend to rely on specific methods that are more effective
# or easier to execute. Other attack types contribute comparatively less, showing an uneven
# distribution in attack strategies.
#
# Overall, the data highlights a strong preference for certain attack methods over others.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights can create a positive business impact.
#
# By understanding the most common attack types, organizations can design targeted
# security measures, such as improving surveillance systems, strengthening infrastructure,
# and implementing specific safety protocols to prevent such attacks.
#
# However, the insights also indicate negative growth factors. The dominance of attack
# types like bombings can lead to severe damage to infrastructure, increased casualties,
# and higher security costs. This can discourage investments, affect business operations,
# and reduce public confidence in affected areas.
#
# Thus, while the insights support better preparedness, they also highlight risks that
# can negatively impact economic growth.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
region_data = (df.groupby('region_txt').size().sort_values(ascending=False))

# Plot (area chart - unique choice)
plt.figure(figsize=(12,6))
plt.fill_between(region_data.index, region_data.values)

plt.title("Region-wise Distribution of Terrorist Attacks")
plt.xlabel("Region")
plt.ylabel("Number of Attacks")

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# An area chart is used to visualize the distribution of attacks across regions.
# It helps in showing the magnitude of attacks and highlights regions with higher impact
# in a visually appealing way.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that certain regions, such as the Middle East & North Africa
# and South Asia, experience significantly higher numbers of attacks compared to others.
#
# This indicates that terrorism is concentrated in specific geographical areas,
# while some regions remain relatively less affected.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights can contribute to a positive business impact.
#
# By identifying regions with high terrorist activity, businesses can make strategic
# decisions such as choosing safer locations for expansion, improving supply chain routes,
# and implementing region-specific security measures. This helps in minimizing risks
# and ensuring operational continuity.
#
# However, the insights also highlight negative growth in high-risk regions.
# Frequent terrorist activities in regions like the Middle East & North Africa and South Asia
# can lead to economic instability, reduced foreign investments, and a decline in tourism.
#
# These factors create an unfavorable business environment, resulting in slower economic
# growth and increased uncertainty for businesses operating in those regions.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
if 'total_casualties' not in df.columns:
    df['total_casualties'] = df['nkill'] + df['nwound']

# Plot histogram
plt.figure(figsize=(10,6))
plt.hist(df['total_casualties'], bins=50)

plt.title("Distribution of Total Casualties per Attack")
plt.xlabel("Number of Casualties")
plt.ylabel("Frequency")

plt.yscale('log')  # makes distribution clearer (unique touch)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram is used to understand the distribution of casualties across incidents.
# It helps identify whether most attacks result in low or high casualties and reveals
# the spread and frequency of extreme events.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The majority of terrorist attacks result in relatively low casualties,
# while a small number of attacks cause extremely high casualties.
#
# This indicates a highly skewed distribution, where rare but severe events
# have a significant impact compared to most incidents.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights can create a positive business impact.
#
# By understanding that most attacks result in low casualties while a few lead to extremely
# high casualties, organizations can develop better risk management strategies. Businesses
# can focus on emergency preparedness, crisis response planning, and infrastructure safety
# to minimize damage during high-impact events.
#
# However, the presence of rare but high-casualty attacks indicates negative growth factors.
# Such events can cause significant loss of life, large-scale infrastructure damage,
# and economic disruption. These incidents reduce investor confidence, increase insurance
# costs, and can lead to long-term instability in affected regions.
#
# Thus, while the insights support better preparedness, they also highlight risks that can
# negatively impact business growth and economic stability.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# To achieve the business objective, the client should focus on risk-aware
# decision making and proactive planning.
#
# 1. Identify high-risk regions and avoid or limit operations in those areas.
# 2. Strengthen security measures, especially against common attack types like bombings.
# 3. Develop emergency response and crisis management strategies to handle high-impact events.
# 4. Use data-driven insights to plan investments, logistics, and expansion safely.
# 5. Collaborate with local authorities and security agencies for better protection.
#
# By implementing these strategies, the client can minimize risks, protect assets,
# and ensure sustainable business growth even in uncertain environments.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The exploratory data analysis of the global terrorism dataset reveals important
# patterns and trends in terrorist activities across different years, regions,
# countries, and attack types.
#
# The analysis shows that terrorist incidents have generally increased over time,
# with certain regions and countries being more affected than others. A few attack
# types, particularly bombings, dominate the dataset, and while most incidents result
# in low casualties, some rare events cause significant impact.
#
# These insights highlight the importance of data-driven decision making for risk
# assessment, security planning, and strategic operations. By understanding these
# patterns, organizations and policymakers can take preventive measures, allocate
# resources effectively, and minimize potential risks.
#
# Overall, the study provides valuable insights that can support safer business
# operations and contribute to better preparedness in high-risk environments.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
